# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaJG/AGP2021/blob/main/Nudos_aleatorios_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Un nudo de *Lissajous* K en $\mathbb{R}^{3}$ tiene la parametrización, $K(t)= (x(t),y(t),z(t))$, donde
#
# \begin{split}
# x(t) =& \cos(n_{x}t+ \phi_{x})\\
# y(t) = & \cos(n_{y}t+\phi_{y})\\
# z(t) =& \cos(n_{z}t+\phi_{z})
# \end{split}
# donde $0 \le t \le 2\pi$, $n_{x},n_{y},n_{z} \in \mathbb{N}$ y $\phi_{x},\phi_{y},\phi{z} \in \mathbb{R}$.

# %%
import numpy as np
import random
from sympy import symbols, cos, sin,pi
from sympy.plotting import plot3d_parametric_line

t = symbols('t')
x= cos(3*t+ 0.7)
y=cos(2*t+0.2)
z= cos(7*t)
plot3d_parametric_line( x, y, z_t, (t, -1*pi, 1*pi))

# %%
import numpy as np
import random
from random import uniform 
from sympy import symbols, cos, sin,pi
from sympy.plotting import plot3d_parametric_line

t = symbols('t')
#Coeficientes enteros 
n_x=random.randint(0,10) 
n_y=random.randint(0,10)
n_z=random.randint(0,10)
#Valor de phi número real cualquiera entre 0 y 1 
phi_1=random.uniform(-10,10)
phi_2=random.uniform(-10,10)
phi_3=random.uniform(-10,10)
#Definición de las coordenadas 
x =  cos(n_x*t + phi_1)
y = cos(n_y*t + phi_2)
z= cos(n_z*t + phi_3)

plot3d_parametric_line(x, y, z, (t, 0*pi, 2*pi))

# %% [markdown]
# Los nudos *Lissajous* es un caso particular del caso general de los nudos de *Fourier*.
#
# Un nudo con coeficientes de Fourier-$(i,j,k)$ está determiniado por las coordenadas
# $$x_{t}=A_{x,1}\cos(n_{x,1}t+ \phi_{x,1})+ \cdots + A_{x,i}\cos(n_{x,i}t+ \phi_{x,i})$$
# $$y_{t}=A_{y,1}\cos(n_{y,1}t+ \phi_{y,1})+ \cdots + A_{y,i}\cos(n_{y,i}t+ \phi_{y,i})$$
# $$z_{t}=A_{z,1}\cos(n_{z,1}t+ \phi_{z,1})+ \cdots + A_{z,i}\cos(n_{z,i}t+ \phi_{z,i})$$
# C. Lamm mostró que todo nudo se puede representar como un nudo de Fourier-$(1,1,k)$.

# %%
import numpy as np
import random
from random import uniform
from sympy import symbols, cos, sin,pi
from sympy.plotting import plot3d_parametric_line

t = symbols('t')
#Coeficientes de x y y son enteros 
ax_1= random.randint(-10,10)
ay_1=random.randint(-10,10)
#Coeficientes  de t de forma entera 
nx_1=random.randint(-10,10)
ny_1=random.randint(-10,10)
phi_1=random.uniform(-10,10)
phi_2=random.uniform(-10,10)
k=2
coeficientes_z=[]
while len(coeficientes_z) <= k-1:
  coeficientes_z.append(random.randint(-10,10))
coeficientes_z_n=[]
while len(coeficientes_z_n) <= k-1:
  coeficientes_z_n.append(random.randint(-10,10))
coeficientes_z_phi=[]
while len(coeficientes_z_phi) <= k-1:
  coeficientes_z_phi.append(uniform(-10,10))

x = ax_1* cos(nx_1*t + phi_1)
y = ay_1 * cos(ny_1*t + phi_2)

z_t=0
for i in range(k):
  z_t= z_t + coeficientes_z[i] * cos (coeficientes_z_n[i] * t + coeficientes_z_phi[i] )

plot3d_parametric_line(x, y, z_t, (t, 0*pi, 2*pi))

# %%
import numpy as np
import random
from random import uniform
from sympy import symbols, cos, sin,pi
from sympy.plotting import plot3d_parametric_line

t = symbols('t')
#Coeficientes de x y y son enteros 
ax_1= random.randint(-10,10)
ay_1=random.randint(-10,10)
#Coeficientes  de t de forma entera 
nx_1=random.randint(-10,10)
ny_1=random.randint(-10,10)
phi_1=uniform(-10,10)
phi_2=uniform(-10,10)
k=10
coeficientes_z=[]
while len(coeficientes_z) <= k-1:
  coeficientes_z.append(random.randint(-10,10))
coeficientes_z_n=[]
while len(coeficientes_z_n) <= k-1:
  coeficientes_z_n.append(random.randint(-10,10))
coeficientes_z_phi=[]
while len(coeficientes_z_phi) <= k-1:
  coeficientes_z_phi.append(uniform(-10,10))

x = ax_1* cos(nx_1*t + phi_1)
y = ay_1 * cos(ny_1*t + phi_2)

z_t=0
for i in range(k):
  z_t= z_t + coeficientes_z[i] * cos (coeficientes_z_n[i] * t + coeficientes_z_phi[i] )

plot3d_parametric_line(x, y, z_t, (t, 0*pi, 2*pi))

# %%
import numpy as np
import random
from sympy import symbols, cos, sin,pi
from sympy.plotting import plot3d_parametric_line

t = symbols('t')
#Coeficientes de x y y son enteros 
ax_1= random.randint(-10,10)
ay_1=random.randint(-10,10)
#Coeficientes  de t de forma entera 
nx_1=random.randint(-10,10)
ny_1=random.randint(-10,10)
phi_1=uniform(-10,10)
phi_2=uniform(-10,10)
#K es un valor aleatorio
k=random.randint(0,20)
coeficientes_z=[]
while len(coeficientes_z) <= k-1:
  coeficientes_z.append(random.randint(-10,10))
coeficientes_z_n=[]
while len(coeficientes_z_n) <= k-1:
  coeficientes_z_n.append(random.randint(-10,10))
coeficientes_z_phi=[]
while len(coeficientes_z_phi) <= k-1:
  coeficientes_z_phi.append(uniform(-10,10))

x = ax_1* cos(nx_1*t + phi_1)
y = ay_1 * cos(ny_1*t + phi_2)

z_t=0
for i in range(k):
  z_t= z_t + coeficientes_z[i] * cos (coeficientes_z_n[i] * t + coeficientes_z_phi[i] )

plot3d_parametric_line(x, y, z_t, (t, 0*pi, 2*pi))

# %%
import numpy as np
import random
from random import uniform
from sympy import symbols, cos, sin,pi
from sympy.plotting import plot3d_parametric_line

t = symbols('t')
#Coeficientes de x y y  
#Uniform regresa un número decimal random N tal que a <= N <=b para a<=b, y b<=N <=a para b< a. El valor de b puede estar o no incluido
# dependiendo del rendondeo de la ecuación a+(b-a) * random()
ax_1= uniform(-10,10)
ay_1=uniform(-10,10)
print(ax_1)
print(ay_1)
#Coeficientes  de t enteros 
nx_1=random.randint(-10,10)
ny_1=random.randint(-10,10)
#Coeficientes de phi cualesquiera reales en un intervalo -10,10 
phi_1=uniform(-10,10)
phi_2=uniform(-10,10)
k=2
coeficientes_z=[]
while len(coeficientes_z) <= k-1:
  coeficientes_z.append(uniform(-10,10))
coeficientes_z_n=[]
while len(coeficientes_z_n) <= k-1:
  coeficientes_z_n.append(random.randint(-10,10))
coeficientes_z_phi=[]
while len(coeficientes_z_phi) <= k-1:
  coeficientes_z_phi.append(uniform(-10,10))

x = ax_1* cos(nx_1*t + phi_1)
y = ay_1 * cos(ny_1*t + phi_2)

z_t=0
for i in range(k):
  z_t= z_t + coeficientes_z[i] * cos (coeficientes_z_n[i] * t + coeficientes_z_phi[i] )

plot3d_parametric_line(x, y, z_t, (t, 0*pi, 2*pi))
# Out:
# -3.787071354072788
# 9.5952542854046

# %%
import numpy as np
import random
from random import uniform
from sympy import symbols, cos, sin,pi
from sympy.plotting import plot3d_parametric_line

t = symbols('t')
#Coeficientes de x y y  
#Uniform regresa un número decimal random N tal que a <= N <=b para a<=b, y b<=N <=a para b< a. El valor de b puede estar o no incluido
# dependiendo del rendondeo de la ecuación a+(b-a) * random()
ax_1= uniform(-10,10)
ay_1=uniform(-10,10)
print(ax_1)
print(ay_1)
#Coeficientes  de t enteros 
nx_1=random.randint(-10,10)
ny_1=random.randint(-10,10)
#Coeficientes de phi cualesquiera reales en un intervalo -10,10 
phi_1=uniform(-10,10)
phi_2=uniform(-10,10)

k=random.randint(0,10)
coeficientes_z=[]
while len(coeficientes_z) <= k-1:
  coeficientes_z.append(uniform(-10,10))
coeficientes_z_n=[]
while len(coeficientes_z_n) <= k-1:
  coeficientes_z_n.append(random.randint(0,10))
coeficientes_z_phi=[]
while len(coeficientes_z_phi) <= k-1:
  coeficientes_z_phi.append(uniform(-10,10))

x = ax_1* cos(nx_1*t + phi_1)
y = ay_1 * cos(ny_1*t + phi_2)

z_t=0
for i in range(k):
  z_t=z_t + coeficientes_z[i] * cos (coeficientes_z_n[i] * t + coeficientes_z_phi[i] )

plot3d_parametric_line(x, y, z_t, (t, 0*pi, 2*pi))
# Out:
# -9.283320820469767
# 0.3491859941173985

# %%
import numpy as np
import random
from random import uniform
from sympy import symbols, cos, sin,pi
from sympy.plotting import plot3d_parametric_line

t = symbols('t')
#Coeficientes de x y y  
#Uniform regresa un número decimal random N tal que a <= N <=b para a<=b, y b<=N <=a para b< a. El valor de b puede estar o no incluido
# dependiendo del rendondeo de la ecuación a+(b-a) * random()
ax_1= uniform(-10,10)
ay_1=uniform(-10,10)
print(ax_1)
print(ay_1)
#Coeficientes  de t no enteros 
nx_1=random.uniform(-10,10)
ny_1=random.uniform(-10,10)
#Coeficientes de phi cualesquiera reales en un intervalo -10,10 
phi_1=uniform(-10,10)
phi_2=uniform(-10,10)

k=2
coeficientes_z=[]
while len(coeficientes_z) <= k-1:
  coeficientes_z.append(uniform(-10,10))
coeficientes_z_n=[]
while len(coeficientes_z_n) <= k-1:
  coeficientes_z_n.append(random.uniform(0,10))
coeficientes_z_phi=[]
while len(coeficientes_z_phi) <= k-1:
  coeficientes_z_phi.append(uniform(-10,10))

x = ax_1* cos(nx_1*t + phi_1)
y = ay_1 * cos(ny_1*t + phi_2)

z_t=0
for i in range(k):
  z_t= z_t + coeficientes_z[i] * cos (coeficientes_z_n[i] * t + coeficientes_z_phi[i] )

plot3d_parametric_line(x, y, z_t, (t, 0*pi, 2*pi))
# Out:
# -9.663064535626242
# -5.618856612249241

# %%
import numpy as np
import random
from random import uniform
from sympy import symbols, cos, sin,pi
from sympy.plotting import plot3d_parametric_line

t = symbols('t')
#Coeficientes de x y y  
#Uniform regresa un número decimal random N tal que a <= N <=b para a<=b, y b<=N <=a para b< a. El valor de b puede estar o no incluido
# dependiendo del rendondeo de la ecuación a+(b-a) * random()
ax_1= random.randint(-10,10)
ay_1=random.randint(-10,10)
#Coeficientes  de t no enteros 
nx_1=random.uniform(-10,10)
ny_1=random.uniform(-10,10)
#Coeficientes de phi cualesquiera reales en un intervalo -10,10 
phi_1=uniform(-10,10)
phi_2=uniform(-10,10)

k=2
coeficientes_z=[]
while len(coeficientes_z) <= k-1:
  coeficientes_z.append(random.randint(-10,10))
coeficientes_z_n=[]
while len(coeficientes_z_n) <= k-1:
  coeficientes_z_n.append(random.uniform(-10,10))
coeficientes_z_phi=[]
while len(coeficientes_z_phi) <= k-1:
  coeficientes_z_phi.append(uniform(-10,10))

x = ax_1* cos(nx_1*t + phi_1)
y = ay_1 * cos(ny_1*t + phi_2)

z_t=0
for i in range(k):
  z_t= z_t + coeficientes_z[i] * cos (coeficientes_z_n[i] * t + coeficientes_z_phi[i] )

plot3d_parametric_line(x, y, z_t, (t, 0*pi, 2*pi))

# %%
import numpy as np
import random
from random import uniform
from sympy import symbols, cos, sin,pi
from sympy.plotting import plot3d_parametric_line

t = symbols('t')
i = random.randint(0,10)
j = random.randint(0,10)
k = random.randint(0,10)

A_xi = np.random.randn(i)
A_yj = np.random.randn(j)    
A_zk = np.random.randn(k)

n_xi = np.random.randint(-20,20,(i))
n_yj = np.random.randint(-20,20,(j))
n_zk = np.random.randint(-20,20,(k))

phi_xi = np.random.randn(i)    
phi_yj = np.random.randn(j)
phi_zk = np.random.randn(k)
    
x_t = 0
y_t = 0
z_t = 0
for ii in range(i):
  x_t = x_t + A_xi[ii] * cos(n_xi[ii]*t  + phi_xi[ii])
for jj in range(j):
  y_t = y_t + A_yj[jj]* cos(n_yj[jj] *t + phi_yj[jj])
for kk in range(k):
  z_t = z_t + A_zk[kk]* cos(n_zk[kk]* t  + phi_zk[kk])

print(x_t)
print(y_t)
print(z_t)

plot3d_parametric_line(x_t, y_t, z_t, (t, 0*pi, 2*pi))
# Out:
# 0.604214498055197*cos(2*t - 0.572577903674891) - 1.38096413578599*cos(4*t - 0.325695430740837) - 0.130990890810649*cos(8*t + 2.03097773957172) + 1.3355003965876*cos(9*t + 1.15135170247015) - 0.449636551292833*cos(10*t - 0.0256815200331523) - 0.33013886167428*cos(18*t + 0.472329369630168)
# -1.43641956492808*cos(4*t + 1.61398855218317) - 0.173946482062869*cos(9*t - 1.60387538619966) + 0.377460827697294*cos(11*t + 0.0410186477121014) - 0.275263153414755*cos(15*t + 0.0947933976274101) - 0.990930558306837*cos(15*t + 1.25156782452023) + 1.58372954254684*cos(18*t - 0.649789466114848) + 0.422433420224102*cos(18*t + 0.678032755833923)
# ...
